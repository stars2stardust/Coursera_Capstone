# %% [markdown]
# <h1>Coursera IBM Data Science Capstone Notebook</h1>
#
# <p>This notebook will primarily be used for the capstone project. This notebook is written by Rachel Alexander. </p>

# %%
#import libraries
import numpy as np
import pandas as pd

pri
